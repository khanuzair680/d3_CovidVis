# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
verbose=True

# %%
df = pd.read_csv(r'csv/enrollments.csv')
# Out:
# /var/folders/84/w6979yl547ddlndc7496yzsw0000gn/T/ipykernel_32111/3555196855.py:1: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r'csv/enrollments.csv')

# %%
# Convert year float to dt object
df['year'] = pd.to_datetime(df['year'], format='%Y')
df['year'] = df['year'].apply(lambda x: pd.to_datetime(x))

# df['foundedyr'] = pd.to_datetime(df['foundedyr'], format='%Y',errors = 'coerce')
# df['foundedyr'] = df['foundedyr'].apply(lambda x: pd.to_datetime(x))

# %%
df.head()
# Out:
#        country countrycode      region incomegroup      iau_id       iau_id1  \
# 0  afghanistan         AFG  South Asia  Low income  IAU-000810  IAU-000810-1
# 1  afghanistan         AFG  South Asia  Low income  IAU-000810  IAU-000810-1
# 2  afghanistan         AFG  South Asia  Low income  IAU-000810  IAU-000810-1
# 3  afghanistan         AFG  South Asia  Low income  IAU-000810  IAU-000810-1
# 4  afghanistan         AFG  South Asia  Low income  IAU-000810  IAU-000810-1
#
#               eng_name            orig_name  foundedyr  yrclosed  ...  \
# 0  Alberoni University  Alberoni University     1998.0       NaN  ...
# 1  Alberoni University  Alberoni University     1998.0       NaN  ...
# 2  Alberoni University  Alberoni University     1998.0       NaN  ...
# 3  Alberoni University  Alberoni University     1998.0       NaN  ...
# 4  Alberoni University  Alberoni University     1998.0       NaN  ...
#
#    divisions total_fields unique_fields specialized  merger  noiau       year  \
# 0        NaN          NaN           NaN         0.0     0.0    0.0 2000-01-01
# 1        NaN          NaN           NaN         0.0     0.0    0.0 2005-01-01
# 2        NaN          NaN           NaN         0.0     0.0    0.0 2010-01-01
# 3        NaN          NaN           NaN         0.0     0.0    0.0 2015-01-01
# 4        9.0         22.0          21.0         0.0     0.0    0.0 2020-01-01
#
#    students5_interpolated  students5_extrapolated  students5_estimated
# 0                     NaN                  1546.0               1546.0
# 1                     NaN                  2106.0               2106.0
# 2                  2317.0                  2317.0               2317.0
# 3                  1835.0                  1835.0               1835.0
# 4                     NaN                  1901.0               1901.0
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161560 entries, 0 to 161559
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   country                 161560 non-null  object
#  1   countrycode             159698 non-null  object
#  2   region                  159698 non-null  object
#  3   incomegroup             159691 non-null  object
#  4   iau_id                  161553 non-null  object
#  5   iau_id1                 161553 non-null  object
#  6   eng_name                161553 non-null  object
#  7   orig_name               138474 non-null  object
#  8   foundedyr               161553 non-null  float64
#  9   yrclosed                460 non-null     float64
#  10  private01               161553 non-null  float64
#  11  coordinates             138352 non-null  object
#  12  latitude                138352 non-null  object
#  13  longitude               138352 non-null  object
#  14  phd_granting            161553 non-null  float64
#  15  m_granting              21208 non-null   float64
#  16  b_granting              21208 non-null   float64
#  17  divisions               21208 non-null   float64
#  18  total_fields            21208 non-null   float64
#  19  unique_fields           21208 non-null   float64
#  20  specialized             161553 non-null  float64
#  21  merger                  161553 non-null  float64
#  22  noiau                   161553 non-null  float64
#  23  year                    161553 non-null  datetime64[ns]
#  24  students5_interpolated  53960 non-null   float64
#  25  students5_extrapolated  105598 non-null  float64
#  26  students5_estimated     142831 non-null  float64
# dtypes: datetime64[ns](1), float64(15), object(11)
# memory usage: 33.3+ MB

# %%
# Drop useless columns
df.drop(['iau_id', 'iau_id1','yrclosed','orig_name','students5_interpolated','students5_extrapolated','total_fields','merger','unique_fields','noiau','specialized'], axis=1, inplace=True)
cols_name_map = {'country': 'Country', 'eng_name': 'University', 'foundedyr': 'Founded in', 'b_granting': 'Bachelor', 'm_granting': 'Master', 'phd_granting': 'PhD', 'students5_estimated': 'Number of Student'}
# Rename
df = df.rename(columns=cols_name_map)

# %%
# Fixing nan
df = df[~df['latitude'].isna()]
df = df[~df['longitude'].isna()]
df = df[~df['Number of Student'].isna()]

# %%
# format and refactor values to be more user-friendly and nice-to-see in the map
df['Country'] = df['Country'].apply(lambda x: x.title())
df['University'] = df['University'].apply(lambda x: x.title())
df['University'] = df['University'].apply(lambda x: x.replace('\\N', ' - ').title())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127649 entries, 0 to 161559
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Country            127649 non-null  object
#  1   countrycode        127102 non-null  object
#  2   region             127102 non-null  object
#  3   incomegroup        127102 non-null  object
#  4   University         127649 non-null  object
#  5   Founded in         127649 non-null  float64
#  6   private01          127649 non-null  float64
#  7   coordinates        127649 non-null  object
#  8   latitude           127649 non-null  object
#  9   longitude          127649 non-null  object
#  10  PhD                127649 non-null  float64
#  11  Master             20506 non-null   float64
#  12  Bachelor           20506 non-null   float64
#  13  divisions          20506 non-null   float64
#  14  year               127649 non-null  datetime64[ns]
#  15  Number of Student  127649 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(8)
# memory usage: 16.6+ MB

# %%
## Find different divisions
df.divisions
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         9.0
#          ...
# 161555    NaN
# 161556    NaN
# 161557    6.0
# 161558    NaN
# 161559    4.0
# Name: divisions, Length: 127649, dtype: float64

# %% [markdown]
# ## CALCULATE TOTAL STUDENTS FROM EACH COUNTRY EVERY YEAR.
# STUDENTS X COUNTRY

# %%
grouped = df.groupby(['Country', 'year'])['Number of Student'].sum().unstack(0).reset_index()
grouped = grouped.fillna(0)
grouped = grouped.rename(columns={'year':'time'})
grouped.to_csv('csv/processed/students_by_country_year.csv', index=False)

# %% [markdown]
# ## FIND STUDENTS IN EACH INCOME GROUP FROM FOR EVERY COUNTRY

# %%
df.incomegroup.value_counts()
# Out:
# Upper middle income    48007
# High income            47556
# Lower middle income    27116
# Low income              4423
# Name: incomegroup, dtype: int64

# %% [markdown]
# ## Count enrolments from Each Country

# %%
df['Number of Student'] = df['Number of Student'].fillna(0).apply(int)

# %%
# Count enrolments from each country

country_counts = df.groupby(['Country','countrycode','region'])['Number of Student'].agg('sum').reset_index()
country_counts = country_counts.sort_values(by='Number of Student')
country_counts = country_counts.rename(columns={'Number of Student': 'students'})
country_counts.to_csv('csv/processed/country_enrolment_processed.csv',index=False)
country_counts
# Out:
#                    Country countrycode                       region  students
# 148             Seychelles         SYC           Sub-Saharan Africa       237
# 141  Saint Kitts And Nevis         KNA  Latin America and Caribbean       239
# 170                  Tonga         TON        East Asia and Pacific       324
# 144  Sao Tome And Principe         STP           Sub-Saharan Africa       371
# 38                 Comoros         COM           Sub-Saharan Africa       646
# ..                     ...         ...                          ...       ...
# 139     Russian Federation         RUS      Europe and Central Asia  34933929
# 134            Philippines         PHL        East Asia and Pacific  38929878
# 179          United States         USA                North America  53203189
# 35                   China         CHN        East Asia and Pacific  63595771
# 77                   India         IND                   South Asia  97583864
#
# [187 rows x 4 columns]

# %% [markdown]
# ## Enrolments from each region

# %%
# Count enrolments from each country
region_counts = df.groupby(['region'])['Number of Student'].agg('sum').reset_index()
# country_counts = country_counts.sort_values(by='Number of Student')
region_counts = region_counts.rename(columns={'Number of Student': 'students'})
region_counts.to_csv('csv/processed/region_enrolment_processed.csv',index=False)
region_counts
# Out:
#                          region   students
# 0         East Asia and Pacific  213809094
# 1       Europe and Central Asia  224219259
# 2   Latin America and Caribbean  134933052
# 3  Middle East and North Africa   58774877
# 4                 North America   68942778
# 5                    South Asia  112108700
# 6            Sub-Saharan Africa   30113437

# %% [markdown]
# ## Enrolments from each country

# %%
# Count enrolments from each country

region_counts = df.groupby(['countrycode'])['Number of Student'].agg('sum').reset_index()
region_counts = region_counts.rename(columns={'Number of Student': 'students'})
region_counts.to_csv('csv/processed/country_student_count.csv',index=False)
region_counts


region_counts_avg = df.groupby(['countrycode'])['Number of Student'].agg('mean').reset_index()
region_counts_avg = region_counts_avg.rename(columns={'Number of Student': 'students'})
region_counts_avg
# Out:
#     countrycode      students
# 0           ABW    276.428571
# 1           AFG   2303.012448
# 2           AGO   4492.122137
# 3           ALB   3701.854305
# 4           AND    743.100000
# ..          ...           ...
# 182         WSM    707.058824
# 183         YEM   8213.534247
# 184         ZAF  15983.404531
# 185         ZMB   1989.102941
# 186         ZWE   5041.333333
#
# [187 rows x 2 columns]

# %%
region_counts
# Out:
#     countrycode  students
# 0           ABW      3870
# 1           AFG    555026
# 2           AGO    588468
# 3           ALB    558980
# 4           AND      7431
# ..          ...       ...
# 182         WSM     12020
# 183         YEM    599588
# 184         ZAF   4938872
# 185         ZMB    270518
# 186         ZWE    423472
#
# [187 rows x 2 columns]

# %% [markdown]
# ## Count income group from each country

# %%
income_group_counts = df.groupby(['Country','incomegroup'])['Number of Student'].sum().unstack(1)
income_group_counts
# Out:
# incomegroup  High income  Low income  Lower middle income  Upper middle income
# Country
# Afghanistan          NaN    555026.0                  NaN                  NaN
# Albania              NaN         NaN                  NaN             558980.0
# Algeria              NaN         NaN            4493616.0                  NaN
# Andorra           7431.0         NaN                  NaN                  NaN
# Angola               NaN         NaN             588468.0                  NaN
# ...                  ...         ...                  ...                  ...
# Venezuela            NaN         NaN                  NaN            5862043.0
# Vietnam              NaN         NaN            6963903.0                  NaN
# Yemen                NaN    599588.0                  NaN                  NaN
# Zambia               NaN         NaN             270518.0                  NaN
# Zimbabwe             NaN         NaN             423472.0                  NaN
#
# [187 rows x 4 columns]

# %% [markdown]
# ## Count enrolment from Each Income Group

# %%
# Count enrolments from each income group
income_group_counts = df.groupby(['incomegroup'])['Number of Student'].agg('sum').reset_index()
# Normalize the values between 0 and 100 in %.
total_sum = income_group_counts['Number of Student'].sum()
income_group_counts['count_percentage'] = income_group_counts['Number of Student'].apply(lambda x: (x / total_sum) * 100)
# Write to csv
income_group_counts.to_csv('csv/processed/income_group_count.csv',index=False)
income_group_counts
# Out:
#            incomegroup  Number of Student  count_percentage
# 0          High income          279100784         33.111922
# 1           Low income           21003981          2.491868
# 2  Lower middle income          228999209         27.167978
# 3  Upper middle income          313797223         37.228233

# %% [markdown]
# ## Countrywise incomegroup.

# %%
income_group_by_country = df.groupby(['Country', 'incomegroup'])['Number of Student'].agg('sum').reset_index()
income_group_by_country
# Out:
#          Country          incomegroup  Number of Student
# 0    Afghanistan           Low income             555026
# 1        Albania  Upper middle income             558980
# 2        Algeria  Lower middle income            4493616
# 3        Andorra          High income               7431
# 4         Angola  Lower middle income             588468
# ..           ...                  ...                ...
# 182    Venezuela  Upper middle income            5862043
# 183      Vietnam  Lower middle income            6963903
# 184        Yemen           Low income             599588
# 185       Zambia  Lower middle income             270518
# 186     Zimbabwe  Lower middle income             423472
#
# [187 rows x 3 columns]

# %% [markdown]
# ## Total enrolments yearwise and from each incomegroup

# %%
# income_group_by_year = df.groupby(['year', 'incomegroup'])['Number of Student'].agg('sum').unstack(1)
income_group_by_year = df.groupby(['year', 'incomegroup']).agg({'Number of Student': 'sum'}).unstack(1)
income_group_by_year.columns=income_group_by_year.columns.droplevel()
# income_group_by_year = income_group_by_year.reset_index()
income_group_by_year.to_csv('csv/processed/income_group_by_year.csv')

# income_group_by_year = df.groupby('incomegroup').agg({'Number of Student': 'sum'}).reset_index()
income_group_by_year
# Out:
# incomegroup  High income  Low income  Lower middle income  Upper middle income
# year
# 1950-01-01       3865348        9749               675920               830549
# 1955-01-01       4521373       19926               908247              1168170
# 1960-01-01       5379428       82146              1659381              2244256
# 1965-01-01       6686537      147164              2671820              3220454
# 1970-01-01       8705792      258139              4152659              4657680
# 1975-01-01      11160007      397690              6564630              7044174
# 1980-01-01      13402261      576380              8141100              9598727
# 1985-01-01      15463393      697138             10326365             12564164
# 1990-01-01      18557702      877582             12724344             15410818
# 1995-01-01      22126059     1136080             15941731             19474968
# 2000-01-01      25817275     1635911             20538558             26279236
# 2005-01-01      29765366     2307850             25720465             35927119
# 2010-01-01      33710848     3235062             32379365             48428587
# 2015-01-01      37555867     4347416             38780900             59363750
# 2020-01-01      42383528     5275748             47813724             67584571

# %%
# Out:
# year                 1950-01-01  1955-01-01  1960-01-01  1965-01-01  \
# incomegroup
# High income             3865348     4521373     5379428     6686537
# Low income                 9749       19926       82146      147164
# Lower middle income      675920      908247     1659381     2671820
# Upper middle income      830549     1168170     2244256     3220454
#
# year                 1970-01-01  1975-01-01  1980-01-01  1985-01-01  \
# incomegroup
# High income             8705792    11160007    13402261    15463393
# Low income               258139      397690      576380      697138
# Lower middle income     4152659     6564630     8141100    10326365
# Upper middle income     4657680     7044174     9598727    12564164
#
# year                 1990-01-01  1995-01-01  2000-01-01  2005-01-01  \
# incomegroup
# High income            18557702    22126059    25817275    29765366
# Low income               877582     1136080     1635911     2307850
# Lower middle income    12724344    15941731    20538558    25720465
# Upper middle income    15410818    19474968    26279236    35927119
#
# year                 2010-01-01  2015-01-01  2020-01-01
# incomegroup
# High income            33710848    37555867    42383528
# Low income              3235062     4347416     5275748
# Lower middle income    32379365    38780900    47813724
# Upper middle income    48428587    59363750    67584571

# %% [markdown]
# ## Count enrolments yearwise

# %%
# year wise enrolment
year_wise = df.groupby(['year'])['Number of Student'].agg('sum').reset_index()
year_wise.to_csv('csv/processed/yearwise_enrolment.csv',index=False)
year_wise
# Out:
#          year  Number of Student
# 0  1950-01-01            5386106
# 1  1955-01-01            6630699
# 2  1960-01-01            9384192
# 3  1965-01-01           12753551
# 4  1970-01-01           17822731
# 5  1975-01-01           25238733
# 6  1980-01-01           31805364
# 7  1985-01-01           39147983
# 8  1990-01-01           47695827
# 9  1995-01-01           58865676
# 10 2000-01-01           74502709
# 11 2005-01-01           94246669
# 12 2010-01-01          118358965
# 13 2015-01-01          140749553
# 14 2020-01-01          163788588

# %% [markdown]
# ## Yearwise Private / Public split

# %%
private_public_by_year = df.groupby(['year', 'private01'])['Number of Student'].agg('sum').unstack(1).reset_index()
private_public_by_year = private_public_by_year.rename(columns = {0.0:'public',1.0:'private'})
private_public_by_year.to_csv('csv/processed/private_by_year.csv',index=False)
private_public_by_year
# Out:
# private01       year     public   private
# 0         1950-01-01    4188509   1197597
# 1         1955-01-01    5222437   1408262
# 2         1960-01-01    7410754   1973438
# 3         1965-01-01   10141061   2612490
# 4         1970-01-01   14278199   3544532
# 5         1975-01-01   20535151   4703582
# 6         1980-01-01   25831690   5973674
# 7         1985-01-01   31447302   7700681
# 8         1990-01-01   37786503   9909324
# 9         1995-01-01   45867791  12997885
# 10        2000-01-01   56682732  17819977
# 11        2005-01-01   68971793  25274876
# 12        2010-01-01   85485311  32873654
# 13        2015-01-01  100832743  39916810
# 14        2020-01-01  118202154  45586434

# %% [markdown]
# ## Merge private-public and income group yearwise data.

# %%
yearwise_merged = pd.merge(income_group_by_year,private_public_by_year,on='year')
cols_name_map = {'High income':'high','Low income':'low_income','Lower middle income':'low_middle_income','Upper middle income':'upper_middle_income'}
yearwise_merged = yearwise_merged.rename(columns=cols_name_map)
#rename the columns 
yearwise_merged.to_csv('csv/processed/yearwise_merged.csv',index=False)

# %%
df.incomegroup.value_counts()
# Out:
# Upper middle income    48007
# High income            47556
# Lower middle income    27116
# Low income              4423
# Name: incomegroup, dtype: int64

# %% [markdown]
# ## Count total universities in each country

# %%
df.groupby(['Country','University'])['Country'].count()
# Out:
# Country      University
# Afghanistan  Afghanistan National Agricultural Sciences And Technology University     2
#              Air University                                                           3
#              Alberoni University                                                      5
#              American University Of Afghanistan                                       3
#              Ariana University                                                        4
#                                                                                      ..
# Zimbabwe     University Of Zimbabwe                                                  14
#              University Solution                                                     13
#              Women'S University In Africa                                             4
#              Zimbabwe Ezekiel Gut University                                          2
#              Zimbabwe Open University                                                 6
# Name: Country, Length: 15572, dtype: int64

# %% [markdown]
# ## Count total universities in the world

# %%
df.University.nunique()
# Out:
# 15426

# %%
#Count students studying in 2020
import datetime as dt
df['Date'] = pd.to_datetime(df['year'])

include = df[df['Date'].dt.year == 2020]

# %%
total_students_2020 = include.groupby(['year'])['Number of Student'].agg('sum').reset_index()

# %%
total_students_2020
# Out:
#         year  Number of Student
# 0 2020-01-01          163788588

# %%
df = df.fillna(0)

# %%
df.value_counts('region')
# Out:
# region
# East Asia and Pacific           37827
# Europe and Central Asia         36540
# Latin America and Caribbean     19733
# North America                   12470
# South Asia                       7080
# Sub-Saharan Africa               6967
# Middle East and North Africa     6485
# 0                                 547
# dtype: int64

# %% [markdown]
# ## Group data by country

# %%
# df
country_data = df.groupby(['University','latitude','longitude','Founded in','incomegroup','private01']).agg({'Number of Student':'sum'})
# country_data
country_data.loc[country_data['Number of Student'] > 500000].to_csv('csv/processed/university_merged.csv')
# country_data.

# df.keys()

# %% [markdown]
# # Create dataframe with the following information
# ## Country Countrycode oldest-UniName year-founded bachelors masters phd low-income high-income etc

# %%
# Find oldest university in each country
oldest_university = df.sort_values(by='Founded in').groupby('Country').first().reset_index()

# Print the result
oldest_university

rslt_df = oldest_university.loc[oldest_university['countrycode'] =='USA']
rslt_df
# Out:
#            Country countrycode         region  incomegroup  \
# 185  United States         USA  North America  High income
#
#              University  Founded in  private01              coordinates  \
# 185  Harvard University      1636.0        1.0  42.3770029, -71.1166601
#
#        latitude    longitude  PhD  Master  Bachelor       year  \
# 185  42.3770029  -71.1166601  0.0     0.0       0.0 1965-01-01
#
#      Number of Student       Date
# 185              18365 1965-01-01

# %% [markdown]
# ### Count private and public uni in every country

# %%
# Count the number of private and not private colleges for each country
count = df.groupby(['countrycode']).agg({'private01':['sum','size']}).reset_index()
count.columns = ['countrycode','Private','Not private']
count['Not private'] = count['Not private'] - count['Private']

# Print the result
count
# Out:
#     countrycode  Private  Not private
# 0             0    318.0        229.0
# 1           ABW      0.0         14.0
# 2           AFG     45.0        196.0
# 3           AGO     77.0         54.0
# 4           ALB     54.0         97.0
# ..          ...      ...          ...
# 183         WSM      0.0         17.0
# 184         YEM     26.0         47.0
# 185         ZAF    110.0        199.0
# 186         ZMB     95.0         41.0
# 187         ZWE     26.0         58.0
#
# [188 rows x 3 columns]

# %% [markdown]
# ## Count masters, bachelors and PhD for each country.

# %%
# Sum the values of the 'masters', 'bachelors', and 'phd' columns for each group of 'Country'
count_degrees = df.groupby('countrycode').agg({'Master': 'sum', 'Bachelor': 'sum', 'PhD': 'sum'}).reset_index()
cols_name_map = {'country': 'Country', 'Master': 'total_masters', 'Bachelor': 'total_bachelor', 'PhD': 'total_phd'}
count_degrees = count_degrees.rename(columns=cols_name_map)

# Calculate the total number of degrees for each row
count_degrees['total'] = count_degrees['total_masters'] + count_degrees['total_bachelor'] + count_degrees['total_phd']

# Calculate the percentage of each degree for each row
count_degrees['percent_masters'] = count_degrees['total_masters'] / count_degrees['total'] * 100
count_degrees['percent_bachelor'] = count_degrees['total_bachelor'] / count_degrees['total'] * 100
count_degrees['percent_phd'] = count_degrees['total_phd'] / count_degrees['total'] * 100

# Delete useless columns
count_degrees = count_degrees.drop(['total_masters','total_bachelor','total_phd'],axis=1)
count_degrees
# Show the resulting dataframe
# print(count_degrees)
# Out:
#     countrycode  total  percent_masters  percent_bachelor  percent_phd
# 0           ABW    8.0        50.000000         50.000000     0.000000
# 1           AFG   68.0        25.000000         66.176471     8.823529
# 2           AGO   43.0         0.000000        100.000000     0.000000
# 3           ALB   64.0        40.625000         42.187500    17.187500
# 4           AND    3.0         0.000000          0.000000   100.000000
# ..          ...    ...              ...               ...          ...
# 182         WSM   10.0        40.000000         40.000000    20.000000
# 183         YEM   54.0        38.888889         61.111111     0.000000
# 184         ZAF   67.0        40.298507         29.850746    29.850746
# 185         ZMB   52.0        36.538462         42.307692    21.153846
# 186         ZWE   34.0        38.235294         38.235294    23.529412
#
# [187 rows x 5 columns]

# %% [markdown]
# ## count universities in each country

# %%
# Group the data by country and count the number of universities
country_counts = df.groupby('countrycode').count()
# Get the number of universities for each country
university_counts = country_counts['University'].reset_index()
# rename column
cols_name_map = {'University':'total_universities'}
university_counts = university_counts.rename(columns=cols_name_map)
# university_counts.sort_values(by='total_universities', ascending=False)

# %% [markdown]
# ### Merge both the datasets

# %%
# Merge the dataframes on the 'Country' column
merged_df = pd.merge(count, oldest_university, on='countrycode')
merged_df = pd.merge(merged_df,count_degrees,on='countrycode')
merged_df = pd.merge(merged_df,region_counts,on='countrycode')
merged_df = pd.merge(merged_df,university_counts,on='countrycode')
#convert to year
merged_df['year'] = pd.DatetimeIndex(merged_df['year']).year
merged_df['Date'] = pd.DatetimeIndex(merged_df['Date']).year


# rename the columns 
cols_name_map = {'Number of Student':'students_in_oldest','students':'total_students','Founded in':'founded_in','Not private':'Public'}
merged_df = merged_df.rename(columns=cols_name_map)
# merged_df['founded_in'] = pd.DatetimeIndex(merged_df['founded_in']).year

#remove useless columns 
merged_df = merged_df.drop(['Date','students_in_oldest','coordinates'],axis=1)

#write to csv
merged_df.info()
merged_df.to_csv('csv/processed/merged_dataset.csv',index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187 entries, 0 to 186
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   countrycode         187 non-null    object
#  1   Private             187 non-null    float64
#  2   Public              187 non-null    float64
#  3   Country             187 non-null    object
#  4   region              187 non-null    object
#  5   incomegroup         187 non-null    object
#  6   University          187 non-null    object
#  7   founded_in          187 non-null    float64
#  8   private01           187 non-null    float64
#  9   latitude            187 non-null    object
#  10  longitude           187 non-null    object
#  11  PhD                 187 non-null    float64
#  12  Master              185 non-null    float64
#  13  Bachelor            185 non-null    float64
#  14  year                187 non-null    int64
#  15  total               187 non-null    float64
#  16  percent_masters     183 non-null    float64
#  17  percent_bachelor    183 non-null    float64
#  18  percent_phd         183 non-null    float64
#  19  total_students      187 non-null    int64
#  20  total_universities  187 non-null    int64
# dtypes: float64(11), int64(3), object(7)
# memory usage: 32.1+ KB

# %%
rslt_df = merged_df.loc[merged_df['countrycode'] =='USA']
rslt_df
# Out:
#     countrycode  Private  Public        Country         region  incomegroup  \
# 178         USA   7541.0  3288.0  United States  North America  High income
#
#              University  founded_in  private01    latitude  ...  PhD  Master  \
# 178  Harvard University      1636.0        1.0  42.3770029  ...  0.0     1.0
#
#      Bachelor  year   total  percent_masters  percent_bachelor  percent_phd  \
# 178       1.0  1965  4142.0        37.059392          41.91212    21.028489
#
#      total_students  total_universities
# 178        53203189               10829
#
# [1 rows x 21 columns]

# %%
merged_df
# Out:
#     countrycode  Private  Public       Country                        region  \
# 0           ABW      0.0    14.0         Aruba   Latin America and Caribbean
# 1           AFG     45.0   196.0   Afghanistan                    South Asia
# 2           AGO     77.0    54.0        Angola            Sub-Saharan Africa
# 3           ALB     54.0    97.0       Albania       Europe and Central Asia
# 4           AND      3.0     7.0       Andorra       Europe and Central Asia
# ..          ...      ...     ...           ...                           ...
# 182         WSM      0.0    17.0         Samoa         East Asia and Pacific
# 183         YEM     26.0    47.0         Yemen  Middle East and North Africa
# 184         ZAF    110.0   199.0  South Africa            Sub-Saharan Africa
# 185         ZMB     95.0    41.0        Zambia            Sub-Saharan Africa
# 186         ZWE     26.0    58.0      Zimbabwe            Sub-Saharan Africa
#
#              incomegroup                                         University  \
# 0            High income                                University Of Aruba
# 1             Low income               Shaheed Rabbani Education University
# 2    Lower middle income                              Kimpa Life University
# 3    Upper middle income                        Sports University Of Tirana
# 4            High income                              University Of Andorra
# ..                   ...                                                ...
# 182  Upper middle income  University Of The South Pacific, School Of Agr...
# 183           Low income                                 Sana'A University.
# 184  Upper middle income                            University Of Cape Town
# 185  Lower middle income        National Institute Of Public Administration
# 186  Lower middle income                                University Solution
#
#      founded_in  private01     latitude  ...  PhD  Master  Bachelor  year  \
# 0        1988.0        0.0   12.5234234  ...  0.0     1.0       1.0  2015
# 1        1913.0        0.0   34.5323516  ...  0.0     1.0       1.0  1970
# 2        1983.0        0.0    -7.617492  ...  0.0     0.0       1.0  2000
# 3        1948.0        0.0   41.3307726  ...  0.0     1.0       1.0  1955
# 4        1988.0        0.0   42.4653237  ...  0.0     0.0       0.0  2015
# ..          ...        ...          ...  ...  ...     ...       ...   ...
# 182      1977.0        0.0  -18.1480462  ...  1.0     1.0       1.0  2020
# 183      1970.0        0.0   15.3485208  ...  0.0     0.0       1.0  1985
# 184      1829.0        0.0   43.6005811  ...  0.0     1.0       1.0  1960
# 185      1963.0        0.0  -15.4192514  ...  0.0     1.0       1.0  1970
# 186      1894.0        1.0   43.6609086  ...  0.0     1.0       1.0  1975
#
#      total  percent_masters  percent_bachelor  percent_phd  total_students  \
# 0      8.0        50.000000         50.000000     0.000000            3870
# 1     68.0        25.000000         66.176471     8.823529          555026
# 2     43.0         0.000000        100.000000     0.000000          588468
# 3     64.0        40.625000         42.187500    17.187500          558980
# 4      3.0         0.000000          0.000000   100.000000            7431
# ..     ...              ...               ...          ...             ...
# 182   10.0        40.000000         40.000000    20.000000           12020
# 183   54.0        38.888889         61.111111     0.000000          599588
# 184   67.0        40.298507         29.850746    29.850746         4938872
# 185   52.0        36.538462         42.307692    21.153846          270518
# 186   34.0        38.235294         38.235294    23.529412          423472
#
#      total_universities
# 0                    14
# 1                   241
# 2                   131
# 3                   151
# 4                    10
# ..                  ...
# 182                  17
# 183                  73
# 184                 309
# 185                 136
# 186                  84
#
# [187 rows x 21 columns]

# %%
university_counts.sort_values(by='total_universities', ascending=False)
# Out:
#     countrycode  total_universities
# 178         USA               10829
# 32          CHN                8877
# 133         PHL                7572
# 86          JPN                7338
# 143         RUS                6795
# ..          ...                 ...
# 156         STP                   5
# 21          BLZ                   4
# 38          COM                   4
# 162         SYC                   3
# 45          DJI                   3
#
# [187 rows x 2 columns]

# %%
#### Country | University | Lat | Long | 

df
# Out:
#             Country countrycode              region          incomegroup  \
# 0       Afghanistan         AFG          South Asia           Low income
# 1       Afghanistan         AFG          South Asia           Low income
# 2       Afghanistan         AFG          South Asia           Low income
# 3       Afghanistan         AFG          South Asia           Low income
# 4       Afghanistan         AFG          South Asia           Low income
# ...             ...         ...                 ...                  ...
# 161555     Zimbabwe         ZWE  Sub-Saharan Africa  Lower middle income
# 161556     Zimbabwe         ZWE  Sub-Saharan Africa  Lower middle income
# 161557     Zimbabwe         ZWE  Sub-Saharan Africa  Lower middle income
# 161558     Zimbabwe         ZWE  Sub-Saharan Africa  Lower middle income
# 161559     Zimbabwe         ZWE  Sub-Saharan Africa  Lower middle income
#
#                              University  Founded in  private01  \
# 0                   Alberoni University      1998.0        0.0
# 1                   Alberoni University      1998.0        0.0
# 2                   Alberoni University      1998.0        0.0
# 3                   Alberoni University      1998.0        0.0
# 4                   Alberoni University      1998.0        0.0
# ...                                 ...         ...        ...
# 161555         Zimbabwe Open University      1993.0        0.0
# 161556         Zimbabwe Open University      1993.0        0.0
# 161557         Zimbabwe Open University      1993.0        0.0
# 161558  Zimbabwe Ezekiel Gut University      2012.0        1.0
# 161559  Zimbabwe Ezekiel Gut University      2012.0        1.0
#
#                     coordinates     latitude   longitude  PhD  Master  \
# 0        35.1270053, 69.3193192   35.1270053   69.319319  0.0     NaN
# 1        35.1270053, 69.3193192   35.1270053   69.319319  0.0     NaN
# 2        35.1270053, 69.3193192   35.1270053   69.319319  0.0     NaN
# 3        35.1270053, 69.3193192   35.1270053   69.319319  0.0     NaN
# 4        35.1270053, 69.3193192   35.1270053   69.319319  0.0     0.0
# ...                         ...          ...         ...  ...     ...
# 161555  -17.6887391, 31.0914758  -17.6887391  31.0914758  0.0     NaN
# 161556  -17.6887391, 31.0914758  -17.6887391  31.0914758  0.0     NaN
# 161557  -17.6887391, 31.0914758  -17.6887391  31.0914758  1.0     1.0
# 161558   -17.3152904, 31.365549  -17.3152904   31.365549  0.0     NaN
# 161559   -17.3152904, 31.365549  -17.3152904   31.365549  0.0     1.0
#
#         Bachelor       year  Number of Student
# 0            NaN 2000-01-01               1546
# 1            NaN 2005-01-01               2106
# 2            NaN 2010-01-01               2317
# 3            NaN 2015-01-01               1835
# 4            1.0 2020-01-01               1901
# ...          ...        ...                ...
# 161555       NaN 2010-01-01              13773
# 161556       NaN 2015-01-01              11662
# 161557       1.0 2020-01-01              22265
# 161558       NaN 2015-01-01               1262
# 161559       1.0 2020-01-01               1347
#
# [127649 rows x 15 columns]
